# %%
import numpy as np
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %% [markdown]
# 0.1 简单的函数

# %%
def my_func(x):
    # 新建一个函数 3x**2+2x+1
    return 3 * x ** 2 + 2 * x + 1


# x = np.linspace(-1000000, 1000000)
x=np.arange(-2, 2,0.01)
y = my_func(x)

# 生成X轴和Y轴函数图像
plt.plot(x, y)

# %%
# # 三角函数
import math
def my_sin(x):
    return np.sin(x)
x = np.linspace(-2, 2)
y= my_sin(x)
plt.plot(x, y)

# %% [markdown]
# 0.2 分段函数

# %%
# 分段函数
def my_分段(x):
    if 0 <= x <= 1:
        return 3 * x
    elif 1 < x <= 3:
        return 3
    elif 3 < x <= 5:
        return x



x = np.linspace(0,5)
y = np.vectorize(my_分段)
y=y(x)
plt.plot(x, y)

# %%
# 分段函数 numpy方法 np.select
# np.select([x < 0, x == 0, x > 0], [x * 3, 3, x])

np.select(([0 <= x <= 1, 1 < x <= 3, 3 < x <= 5], [3 * x, 3, x]))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# d:\OneDrive\GitHub\00_Me\pmgO12Y\python学习\11_数学\0000_函数.ipynb Cell 7 in <cell line: 4>()
#       <a href='vscode-notebook-cell:/d%3A/OneDrive/GitHub/00_Me/pmgO12Y/python%E5%AD%A6%E4%B9%A0/11_%E6%95%B0%E5%AD%A6/0000_%E5%87%BD%E6%95%B0.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> # 分段函数 numpy方法 np.select
#       <a href='vscode-notebook-cell:/d%3A/OneDrive/GitHub/00_Me/pmgO12Y/python%E5%AD%A6%E4%B9%A0/11_%E6%95%B0%E5%AD%A6/0000_%E5%87%BD%E6%95%B0.ipynb#W6sZmlsZQ%3D%3D?line=1'>2</a> # np.select([x < 0, x == 0, x > 0], [x * 3, 3, x])
# ----> <a href='vscode-notebook-cell:/d%3A/OneDrive/GitHub/00_Me/pmgO12Y/python%E5%AD%A6%E4%B9%A0/11_%E6%95%B0%E5%AD%A6/0000_%E5%87%BD%E6%95%B0.ipynb#W6sZmlsZQ%3D%3D?line=3'>4</a> np.select(([0 <= x <= 1, 1 < x <= 3, 3 < x <= 5], [3 * x, 3, x]).any())
#
# ...

# %%
# 分段函数
def my_分段(x):
    if 0<=x<=1:
        return 3 * x
    elif 1<x<=3:
        return 3
    elif 3<x<=5:
        return x


x = np.linspace(0, 5)
y = np.vectorize(my_分段)
y=y(x)
plt.plot(x, y)

# %%
math.sgn(100)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# d:\OneDrive\GitHub\00_Me\pmgO12Y\python学习\11_数学\0000_函数.ipynb Cell 9 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/d%3A/OneDrive/GitHub/00_Me/pmgO12Y/python%E5%AD%A6%E4%B9%A0/11_%E6%95%B0%E5%AD%A6/0000_%E5%87%BD%E6%95%B0.ipynb#X11sZmlsZQ%3D%3D?line=0'>1</a> math.sgn(100)
#
# AttributeError: module 'math' has no attribute 'sgn'

# %%
n=666
x=np.random.rand(n)
y=np.random.rand(n)


plt.scatter(x,y)
plt.grid()

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
